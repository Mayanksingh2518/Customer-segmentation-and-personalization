# %%
import pandas as pd

# Try reading the file with 'latin1' encoding
data = pd.read_csv("OnlineRetail.csv", encoding='latin1')

# Display the first few rows of the dataframe to verify successful loading
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# Handle missing values
data.dropna(subset=['CustomerID'], inplace=True)

# Handle outliers (simple approach)
data = data[(data['Quantity'] > 0) & (data['UnitPrice'] > 0)]

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data[['Quantity', 'UnitPrice']] = scaler.fit_transform(data[['Quantity', 'UnitPrice']])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Spending patterns
sns.histplot(data['UnitPrice'] * data['Quantity'], bins=50)
plt.title('Spending Distribution')
plt.xlabel('Total Spend')
plt.ylabel('Frequency')
plt.show()

# Purchase frequency
purchase_frequency = data.groupby('CustomerID').size()
sns.histplot(purchase_frequency, bins=50)
plt.title('Purchase Frequency Distribution')
plt.xlabel('Number of Purchases')
plt.ylabel('Frequency')
plt.show()

# Customer demographics (Country-wise distribution)
sns.countplot(y='Country', data=data, order=data['Country'].value_counts().index)
plt.title('Country-wise Customer Distribution')
plt.show()
# Out:
# C:\Users\singh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\singh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import datetime as dt

# Assuming the data is already loaded into a pandas DataFrame named 'data'
# data = pd.read_csv('/mnt/data/your_dataset.csv')

# Drop missing CustomerID entries
data.dropna(subset=['CustomerID'], inplace=True)

# Ensure Quantity and UnitPrice are positive
data = data[(data['Quantity'] > 0) & (data['UnitPrice'] > 0)]

# Create 'TotalPrice' column
data['TotalPrice'] = data['Quantity'] * data['UnitPrice']

# Convert 'InvoiceDate' to datetime
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

# Snapshot date (one day after the last invoice date)
snapshot_date = data['InvoiceDate'].max() + dt.timedelta(days=1)

# Create RFM table
rfm = data.groupby('CustomerID').agg({
    'InvoiceDate': lambda x: (snapshot_date - x.max()).days,
    'InvoiceNo': 'count',
    'TotalPrice': 'sum'
})

# Rename columns
rfm.rename(columns={'InvoiceDate': 'Recency', 'InvoiceNo': 'Frequency', 'TotalPrice': 'Monetary'}, inplace=True)
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_6344\770499851.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['TotalPrice'] = data['Quantity'] * data['UnitPrice']
# C:\Users\singh\AppData\Local\Temp\ipykernel_6344\770499851.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

# %%
import pandas as pd
import datetime as dt

# Load the dataset with appropriate encoding
data = pd.read_csv("OnlineRetail.csv", encoding='latin1')

# Convert 'InvoiceDate' to datetime
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

# Create 'TotalPrice' column
data['TotalPrice'] = data['Quantity'] * data['UnitPrice']

# Create snapshot date for recency calculation
snapshot_date = data['InvoiceDate'].max() + dt.timedelta(days=1)

# Create RFM table
rfm = data.groupby('CustomerID').agg({
    'InvoiceDate': lambda x: (snapshot_date - x.max()).days,
    'InvoiceNo': 'count',
    'TotalPrice': 'sum'
})

# Rename columns for RFM
rfm.rename(columns={'InvoiceDate': 'Recency', 'InvoiceNo': 'Frequency', 'TotalPrice': 'Monetary'}, inplace=True)

# Display the first few rows of the RFM table
rfm.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         326          2      0.00
# 12347.0           2        182   4310.00
# 12348.0          75         31   1797.24
# 12349.0          19         73   1757.55
# 12350.0         310         17    334.40

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Normalize RFM values
scaler = StandardScaler()
rfm_normalized = scaler.fit_transform(rfm)

# Apply K-means clustering
kmeans = KMeans(n_clusters=4, random_state=42)
rfm['Cluster'] = kmeans.fit_predict(rfm_normalized)

# Visualize clusters
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x='Recency', y='Frequency', hue='Cluster', data=rfm, palette='viridis')
plt.title('Customer Segments based on RFM')
plt.show()
# Out:
# C:\Users\singh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Create a detailed report with the correct aggregation
report = rfm.groupby('Cluster').agg({
    'Recency': 'mean',
    'Frequency': 'mean',
    'Monetary': 'mean',
    'Recency': 'count'  # This counts the number of customers in each cluster
}).rename(columns={'Recency': 'CustomerCount'}).reset_index()

print(report)

# Visualize monetary value by cluster
sns.boxplot(x='Cluster', y='Monetary', data=rfm)
plt.title('Monetary Value by Customer Segment')
plt.show()
# Out:
#    Cluster  CustomerCount    Frequency       Monetary
# 0        0           3268   106.455630    2012.242253
# 1        1           1095    27.588128     460.668905
# 2        2              5  1013.400000  192103.854000
# 3        3              4  5914.000000   64776.602500

# %%
# Visualize monetary value by cluster
sns.boxplot(x='Cluster', y='Monetary', data=rfm)
plt.title('Monetary Value by Customer Segment')
plt.show()

# %%
# Example: Assign clusters based on some clustering algorithm
# Assuming 'rfm' DataFrame exists and a clustering algorithm is used
from sklearn.cluster import KMeans

# For example purposes, using KMeans
kmeans = KMeans(n_clusters=4)
rfm['Cluster'] = kmeans.fit_predict(rfm[['Recency', 'Frequency', 'Monetary']])
# Out:
# C:\Users\singh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Create detailed report
report = rfm.groupby('Cluster').agg({
    'Recency': 'mean',
    'Frequency': 'mean',
    'Monetary': 'mean',
    'Cluster': 'count'
}).rename(columns={'Cluster': 'CustomerCount'}).reset_index()

print(report)
# Out:
#    Cluster    Recency    Frequency       Monetary  CustomerCount
# 0        0  94.371173    77.282854    1150.834871           4246
# 1        1   3.666667   956.333333  241136.560000              3
# 2        2   7.866667  1510.600000   71423.516000             15
# 3        3  14.824074   492.203704   14989.430833            108

# %%
import pandas as pd
import datetime as dt
from sklearn.cluster import KMeans

# Load the dataset with appropriate encoding
data = pd.read_csv("OnlineRetail.csv", encoding='latin1')

# Convert 'InvoiceDate' to datetime
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

# Create 'TotalPrice' column
data['TotalPrice'] = data['Quantity'] * data['UnitPrice']

# Create snapshot date for recency calculation
snapshot_date = data['InvoiceDate'].max() + dt.timedelta(days=1)

# Create RFM table
rfm = data.groupby('CustomerID').agg({
    'InvoiceDate': lambda x: (snapshot_date - x.max()).days,
    'InvoiceNo': 'count',
    'TotalPrice': 'sum'
})

# Rename columns for RFM
rfm.rename(columns={'InvoiceDate': 'Recency', 'InvoiceNo': 'Frequency', 'TotalPrice': 'Monetary'}, inplace=True)

# Assign clusters (example using KMeans)
kmeans = KMeans(n_clusters=4)
rfm['Cluster'] = kmeans.fit_predict(rfm[['Recency', 'Frequency', 'Monetary']])

# Create detailed report
report = rfm.groupby('Cluster').agg({
    'Recency': 'mean',
    'Frequency': 'mean',
    'Monetary': 'mean',
    'Cluster': 'count'
}).rename(columns={'Cluster': 'CustomerCount'}).reset_index()

print(report)
# Out:
# C:\Users\singh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#    Cluster    Recency    Frequency       Monetary  CustomerCount
# 0        0  94.243180    77.881232    1160.746285           4252
# 1        1   3.666667   956.333333  241136.560000              3
# 2        2   7.866667  1510.600000   71423.516000             15
# 3        3  15.480392   491.666667   15390.295980            102
